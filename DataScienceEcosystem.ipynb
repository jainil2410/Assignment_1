# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ### ScreenShot of EX - 2 :
# ![2-title.png.png](attachment:df0482a1-be30-4938-8457-1f8feee9b755.png)

# %% [markdown]
# ## In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ### __Objectives:__
#
# + List popular languages for Data Science.
# + List popular libraries used by Data Scientist.
# + Which library is used for machine learning.
# + Which library is used for data visualization.
# + State the full-form of SQL.

# %% [markdown]
# ### ScreenShot of EX - 10 :
# ![10-objectives.png](attachment:21a8a30d-49c4-4a1c-aeee-9b6fedb2ea8b.png)

# %% [markdown]
# ### ScreenShot of EX - 3 :
# ![3-intro.png](attachment:25c069e2-c31b-4784-b7e3-0b266de9c515.png)

# %% [markdown]
# ## Some of the popular languages that Data Scientists use are:
# 1. R.Studio
# 2. Python
# 3. C++
# 4. Java

# %% [markdown]
# ### ScreenShot of EX - 4 :
# ![4-dslanguages.png](attachment:a610d3e6-25e6-426b-906d-f4d5575ddf9b.png)

# %% [markdown]
# ### Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas
# 2. Scikit-learn
# 3. Matplotlib
# 4. Seaborn

# %% [markdown]
# ### ScreenShot of EX - 5 :
# ![5-dslibraries.png.png](attachment:749d95df-c93a-4dba-8ed9-bda5599e1c24.png)

# %% [markdown]
# |Data Science Tools |
# | --- |
# |R.Studio |
# |Jupyter Notebook |
# |Visual Studio |

# %% [markdown]
# ### ScreenShot of EX - 6 :
# ![6-dstools.png](attachment:e4df0fdb-dedf-4f1d-9ab3-fbd1c184dd99.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python :

# %% [markdown]
# #### ScreenShot of EX - 7 :
# ![7-introarithmetic.png](attachment:958d5c98-729c-4d39-8cd9-b37d9a1c97c8.png)

# %%
#This is a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %% [markdown]
# ### ScreenShot of EX - 8 :
# ![8-multiplyandaddintegers.png](attachment:1bb752dc-5bf9-4890-92ba-7aee3bbd5b91.png)

# %%
#This will convert 200 minutes to hours by diving by 60
min = 200
hour = min / 60
print(f'{hour} Hrs')
# Out:
# 3.3333333333333335 Hrs

# %% [markdown]
# ### ScreenShot of EX - 9 :
# ![9-hourstominutes.png](attachment:78816350-142f-48ea-8538-e8c0f2b19f45.png)

# %% [markdown]
# ## Author(s)
# Jainil Halpati

# %% [markdown]
# ScreenShot of EX - 11 :
